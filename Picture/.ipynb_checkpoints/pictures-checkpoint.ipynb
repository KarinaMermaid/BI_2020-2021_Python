# %%
import matplotlib.pyplot as plt

# %%
path = 'Cat03.jpg'

# %%
img = plt.imread(path)

# %%
img.shape
# Out:
# (1598, 1600, 3)

# %%
image_cool = img.copy
plt.imshow(image_cool, cmap = 'cool')
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-f19514eff0f6> in <module>
#       1 image_cool = img.copy
# ----> 2 plt.imshow(image_cool, cmap = 'cool')
#       3 plt.axis('off')
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     700         if (self._A.dtype != np.uint8 and
#     701                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 702             raise TypeError("Image data of dtype {} cannot be converted to "
#     703                             "float".format(self._A.dtype))
#     704
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
plt.imshow(img[300: , 600:])

# %%
plt.imshow(img.mean(2))

# %%
def convolve (data, kernel):
    modified = np.zeros_like(data)
    for row in range(1, data.shape[0] - 2):
        for col in range(1, data.shape[1] - 2):
            modified[row, col] = (data[row:row + 3, col:col + 3] * kernel).mean()
    return modified
kernel = np.ones((3,3))
plt.imshow(convolve(img, kernel), cmap = 'inferno')
plt.axis('off')
# Out:
# (-0.5, 1599.5, 1597.5, -0.5)

# %%
fig, axes = plt.subplots(1, 3)

image_1 = img.copy()
image_2 = img.copy()
image_3 = img.copy()

image_1[:, :, 0] = 0
axes[0].imshow(image_1)
axes[0].set_title('Red = 0')

image_2[:, :, 1] = 0
axes[1].imshow(image_2)
axes[1].set_title('Green = 0')

image_3[:, :, 2] = 0
axes[2].imshow(image_3)
axes[2].set_title('Blue = 0')
# Out:
# Text(0.5, 1.0, 'Blue = 0')

# %%
from PIL import Image, ImageFilter
import numpy as np

# %%
pict = Image.open(path)
pict
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1598 at 0x7F0CC4CB70D0>

# %%
data = np.array(pict)

# %%
pict1 = pict.filter(ImageFilter.BLUR)
pict1.show()

# %%
pict2 = pict.filter(ImageFilter.CONTOUR)
pict2.show()

# %%
pict3 = pict.filter(ImageFilter.EMBOSS)
pict3.show()

# %%
pict4 = pict.filter(ImageFilter.MinFilter(3))
pict4.show()

# %%
pict5 = pict.filter(ImageFilter.EDGE_ENHANCE_MORE)
pict5.show()

# %%
pict6 = pict.filter(ImageFilter.FIND_EDGES)
pict6.show()
